# %% [markdown]
# # Qwen Notebook
#
# A learning notebook for understanding Qwen model architecture and training approach.
#
# This notebook was copied from QwenLM/Qwen repository for learning purposes.

# %%
# Example: Loading Qwen model
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Qwen/Qwen-7B"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code=True)
print("Qwen model loaded for experimentation")
